# %%
from keras.models import load_model

# Load the model
loaded_model = load_model('my_model.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23016\816743243.py in <module>
# ----> 1 from keras.models import load_model
#       2
#       3 # Load the model
#       4 loaded_model = load_model('my_model.h5')
#
# c:\Users\Karan Ray Tharu\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\__init__.py in <module>
#      19 """
#      20 from keras import distribute
# ---> 21 from keras import models
#      22 from keras.engine.input_layer import Input
#      23 from keras.engine.sequential import Sequential
#
# c:\Users\Karan Ray Tharu\AppData\Local\Programs\Python\Python37\lib\site-packages\keras\models\__init__.py in <module>
#      16
#      17
# ---> 18 from keras.engine.functional import Functional
#      19 from keras.engine.sequential import Sequential
#      20 from keras.engine.training import Model
#
# ...

# %%
out=loaded_model.predict([[6.7,13.4,2.4,1019.4,82.0,0.6,4.8,11.1]])

# %%
out[0][0]
# Out:
# 220.17043
